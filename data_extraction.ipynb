# %%
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
import matplotlib.pyplot as plt
from pdf2image import convert_from_path
from PIL import Image, ImageEnhance
import numpy as np

# %%
from pdf2image import convert_from_path
import os

pdfs = r"Sample Problem.pdf"

output_dir = 'pages'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

pages = convert_from_path(pdfs, 350)

for i, page in enumerate(pages, start=1):
    image_name = os.path.join(output_dir, f'Page_{i}.png')
    page.save(image_name, "PNG")

# %%
import os
from PIL import Image
import cv2
import numpy as np
from pytesseract import pytesseract
from PIL import ImageEnhance

def enhance_image_before_extracting_data(image_path):
    pil_image = Image.open(image_path)
    opencv_image = cv2.cvtColor(np.array(pil_image), cv2.COLOR_RGB2BGR)
    
    height, width = opencv_image.shape[:2]
    opencv_image = cv2.resize(opencv_image, (width*2, height*2), interpolation=cv2.INTER_CUBIC)
    
    kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    sharpened = cv2.filter2D(opencv_image, -1, kernel)
    
    pil_image = Image.fromarray(cv2.cvtColor(sharpened, cv2.COLOR_BGR2RGB))
    
    enhancer = ImageEnhance.Contrast(pil_image)
    enhanced_image = enhancer.enhance(2.0)
    
    return enhanced_image

def extract_data_from_image(pil_image):
    image = cv2.cvtColor(np.array(pil_image), cv2.COLOR_RGB2BGR)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (3,3), 0)
    thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 30)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    dilate = cv2.dilate(thresh, kernel, iterations=2)
    contours, _ = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    def sort_contours(cnts):
        sorted_cnts = sorted(cnts, key=lambda c: cv2.boundingRect(c)[1])
        tolerance_factor = 10
        row_groups = []
        current_row = [sorted_cnts[0]]
        for contour in sorted_cnts[1:]:
            y = cv2.boundingRect(contour)[1]
            if abs(y - cv2.boundingRect(current_row[0])[1]) < tolerance_factor:
                current_row.append(contour)
            else:
                row_groups.append(current_row)
                current_row = [contour]
        row_groups.append(current_row)
        for row in row_groups:
            row.sort(key=lambda c: cv2.boundingRect(c)[0])
        return [c for row in row_groups for c in row]

    sorted_contours = sort_contours(contours)
    extracted_data = []

    for contour in sorted_contours:
        x, y, w, h = cv2.boundingRect(contour)
        if w > 100 and h > 20:
            roi = image[y:y+h, x:x+w]
            inner_rois = [
                        (w * 0.02, h * 0.05, w * 0.30, h * 0.13), # number - top-left 
                        (w * 0.7, h * 0.05, w * 0.29, h * 0.14),  # epic number - top-right
                        (w * 0.02, h * 0.22, w * 0.7, h * 0.12), # name
                        (w * 0.02, h * 0.34, w * 0.7, h * 0.12), # relative name
                        (w * 0.02, h * 0.44, w * 0.7, h * 0.21), # house number - age - gender
                        ]
            roi_data = []
            for i, (rx, ry, rw, rh) in enumerate(inner_rois):
                inner_roi = roi[int(ry):int(ry+rh), int(rx):int(rx+rw)]
                inner_roi_gray = cv2.cvtColor(inner_roi, cv2.COLOR_BGR2GRAY)
                _, inner_roi_thresh = cv2.threshold(inner_roi_gray, 120, 255, cv2.THRESH_BINARY)
                text = pytesseract.image_to_string(inner_roi_thresh, config='--psm 6')
                roi_data.append(f"ROI {i+1}: {text.strip()}")
            extracted_data.append(roi_data)

    return extracted_data

pages_dir = 'pages'

all_extracted_data = []

for image_file in os.listdir(pages_dir):
    image_path = os.path.join(pages_dir, image_file)
    
    if image_file.endswith('.png'):
        print(f"Processing {image_file}...")
        enhanced_image = enhance_image_before_extracting_data(image_path)
        extracted_text_data = extract_data_from_image(enhanced_image)
        all_extracted_data.extend(extracted_text_data)
# Out:
# Processing Page_1.png...
# Processing Page_2.png...

# %%
all_extracted_data
# Out:
# [['ROI 1: 1',
#   'ROI 2: TXK6940811',
#   'ROI 3: Name : Lina Shaktikurmmar Chavan',
#   'ROI 4: Husband s Name: Shaktikumar Chavan',
#   'ROI 5: House Number :\nAge : 3? Gender : Female'],
#  ['ROI 1: 2?',
#   'ROI 2: TXK6467708',
#   'ROI 3: Name :‘sagar shashikant jadhav',
#   'ROI 4: Father s Name: shashikant jadhav',
#   'ROI 5: House Number :\nAge : 33 Gender : Male'],
#  ['ROI 1: | 3',
#   'ROI 2: TXK6467740',
#   'ROI 3: Name : suresh mahadry kurade',
#   'ROI 4: Father s Name: mahadry kurade',
#   'ROI 5: House Number :\nAge :- 59 Gender : Male'],
#  ['ROI 1: 4',
#   'ROI 2: TXK6467690',
#   'ROI 3: Name : siddharth anil mahajan',
#   "ROI 4: Father's Name: anil mahajan",
#   'ROI 5: House Number :\nAge : 30 Gender : Mala'],
#  ['ROI 1: §',
#   'ROI 2: TAK6894930',
#   'ROI 3: Name : Savita Sambha) Nanavare',
#   'ROI 4: Father s Name: Sambhaji Nanavare',
#   'ROI 5: House Number :\nAge : 25 Gender ! Female'],
#  ['ROI 1: | 6',
#   'ROI 2: TXKO467724',
#   'ROI 3: Name : karan subhas oswal',
#   'ROI 4: Father s Name: subhas oswal',
#   'ROI 5: House Number :\nAge : 30 Gander : Male'],
#  ['ROI 1: ee)',
#   'ROI 2: TXK646/7765',
#   'ROI 3: Name : vaishali hanmant pawar',
#   'ROI 4: Husband s Name: hanmant pawar',
#   'ROI 5: House Number :\nAge : 40 Gender - Female'],
#  ['ROI 1: 8',
#   'ROI 2: TXK6940829',
#   'ROI 3: Name = Ujwal Sunil Rangole',
#   'ROI 4: Father $s Name: Sunil Rangole',
#   'ROI 5: House Number :\nAge : 27 Gender : Male'],
#  ['ROI 1: | 9',
#   'ROI 2: ',
#   'ROI 3: Name : Komal Dhananjay Wadkar',
#   'ROI 4: Father s Name: Dhananjay Wadkar',
#   'ROI 5: House Number :\nAge :- 29 Gender - Female'],
#  ['ROI 1: 10',
#   'ROI 2: TXK6894943',
#   'ROI 3: Name : Ajit Pralhad Yadav',
#   "ROI 4: Father's Name: Pralhad Yadav",
#   'ROI 5: House Number :\nAge : 33 Gender : Male'],
#  ['ROI 1: 11',
#   'ROI 2: TXK7109044',
#   'ROI 3: Name =: pharhana anwar bagwaan',
#   'ROI 4: Fathers Name: anwar bagwaan',
#   'ROI 5: House Number +\nAge : 2? Gender ‘ Female'],
#  ['ROI 1: | 12',
#   'ROI 2: ',
#   'ROI 3: Name : Priyanka Vasant Kasar',
#   'ROI 4: Father s Name: Vasant Kasar',
#   'ROI 5: House Number : -\nAge : 24 Gender : Female'],
#  ['ROI 1: 13',
#   'ROI 2: TXK7 108962',
#   'ROI 3: Name : jakiya tatyabali mulla',
#   'ROI 4: Father s Name: faiyabali mulla',
#   'ROI 5: House Number : -\nAge : 24 Gender : Female'],
#  ['ROI 1: 14',
#   'ROI 2: TXK7 109994',
#   'ROI 3: Name : savita satish pawar',
#   'ROI 4: Husband s Name: satish pawar',
#   'ROI 5: Houses Number : -\nAge : 35 Gender : Female'],
#  ['ROI 1: | 15',
#   'ROI 2: TXK? 110034',
#   'ROI 3: Name : rajat rajendra pawar',
#   'ROI 4: Father s Name: rajendra pawar',
#   'ROI 5: Houses Number : -\nAge : 23 Gender : Male'],
#  ['ROI 1: 16',
#   'ROI 2: TXK7094071',
#   'ROI 3: Name : Swarupa prasad sankapal',
#   'ROI 4: Father s Name: prasad sankapal',
#   'ROI 5: House Number : -\nAge : 23 Gender : Female'],
#  ['ROI 1: 7',
#   'ROI 2: TXK?108921',
#   'ROI 3: Name : nilofar dilawar shaikh',
#   'ROI 4: Father s Name: dilawar shaikh',
#   'ROI 5: House Number : -\nAge : 22 Gender : Female'],
#  ['ROI 1: a:',
#   'ROI 2: TXK7108913',
#   'ROI 3: Name : Karishma Tanveer Waikar',
#   'ROI 4: Father s Name: Tanveer Waikar',
#   'ROI 5: House Number = -\nAge : 28 Gender : Female'],
#  ['ROI 1: 9',
#   'ROI 2: TXK7326317',
#   'ROI 3: Name + RAJASHRI KASAR',
#   'ROI 4: Others: VASANT KASAR',
#   'ROI 5: House Number : 0\nAge : 48 Gender : Female'],
#  ['ROI 1: 20',
#   'ROI 2: TXK 7433097',
#   'ROI 3: Name > Mayuresh Dongare',
#   'ROI 4: Father s Name: Ganesh Dongare',
#   'ROI 5: House Nurmber : Mangalwar peth\nAge : 20 Gender : Male'],
#  ['ROI 1: | E 21',
#   'ROI 2: TXK730507 1',
#   'ROI 3: Name : Mukund Das MudigferLaddad',
#   "ROI 4: Father's Name: MymidNemtaddad",
#   'ROI 5: hoe 80 Gente Erole'],
#  ['ROI 1: ',
#   'ROI 2: TXK7305089',
#   'ROI 3: Name : Padmavati Mukundas Laddad',
#   "ROI 4: Husband's Name: Mukundas Laddad",
#   'ROI 5: House Number : 6a\nAge : 76 Gender : Female'],
#  ['ROI 1: 23',
#   'ROI 2: FRTO775106',
#   'ROI 3: Name : Sunil Mukundas Laddad',
#   'ROI 4: Father s Name: Mukundas Laddad',
#   'ROI 5: House Number : 6a\nAge +53 Gender > Male'],
#  ['ROI 1: | 24',
#   'ROI 2: TXK2769768',
#   'ROI 3: Name : Sneha Sunil Laddad',
#   "ROI 4: Husband's Name: Sunil Laddad",
#   'ROI 5: House Number : 6a\nAge : 51 Gender : Female'],
#  ['ROI 1: 25',
#   'ROI 2: FRTO0775114',
#   'ROI 3: Name :Prtamm Mukudadas Laddad',
#   'ROI 4: Father s Name: Mukudadas Laddad',
#   'ROI 5: House Number : 6a\nAge : 50 Gender : Male'],
#  ['ROI 1: 26',
#   'ROI 2: TXK2769776',
#   'ROI 3: Name : Pallavi Pritam Laddad',
#   'ROI 4: Father s Name: Pritam Laddad',
#   'ROI 5: House Number : 6a\nAge : 47 Gender : Female'],
#  ['ROI 1: | E 2:',
#   'ROI 2: FRT0767830',
#   'ROI 3: Name : Premachandap @pakah Oswal',
#   'ROI 4: Father s Name: BhavanOswal',
#   'ROI 5: '],
#  ['ROI 1: 28',
#   'ROI 2: FRT0767863',
#   'ROI 3: Name : Rekha Vijay Oswal',
#   'ROI 4: Husband s Name: Vijay Oswal',
#   'ROI 5: House Number : 7\nAge : 61 Gender : Female'],
#  ['ROI 1: E 25',
#   'ROI 2: FRT0767855',
#   'ROI 3: Name : Kalavati Premgpgpahaswal',
#   'ROI 4: Hushand s Name ‘Premcrandi Oswal',
#   'ROI 5: House Numb Ve” -\nAge = 51 Gone emale'],
#  ['ROI 1: 30',
#   'ROI 2: FRT0767814',
#   'ROI 3: Name : Ashish Vijay Kumar Oswal',
#   'ROI 4: Father s Name: Vijay Kumar Oswal',
#   'ROI 5: House Number : 7\nAge - 37 Gender - Male'],
#  ['ROI 1: 31',
#   'ROI 2: FRT0765487',
#   'ROI 3: Name - Pramila Pandit Palkar',
#   'ROI 4: Husband s Name: Pandit Palkar',
#   'ROI 5: House Number : 9\nAge : 73 Gender : Female'],
#  ['ROI 1: 32',
#   'ROI 2: FRT0763656',
#   'ROI 3: Name : Narsingh Prasad Pandit Palkar',
#   'ROI 4: Father s Name: Pandit Palkar',
#   'ROI 5: House Number : 9\nAge - 52 Gender : Male'],
#  ['ROI 1: | 33',
#   'ROI 2: FRT0765495',
#   'ROI 3: Name : Shripad Pandit Palkar',
#   'ROI 4: Father s Name: Pandit Palkar',
#   'ROI 5: House Number : 9\nAge : 50 Gender : Male'],
#  ['ROI 1: 34',
#   'ROI 2: FRT0765503',
#   'ROI 3: Name : Alka Narhariprasad Palkar',
#   "ROI 4: Husband's Name: Narhanprasad Palkar",
#   'ROI 5: House Number : 9\nAge : 46 Gender : Female'],
#  ['ROI 1: 35',
#   'ROI 2: FRT0768529',
#   'ROI 3: Name : Smita Shripad Palkar',
#   "ROI 4: Husband's Name: Shripad Palkar",
#   'ROI 5: House Number : 9\nAge : 42 Gander : Female'],
#  ['ROI 1: | 36',
#   'ROI 2: TXK?7 109887',
#   'ROI 3: Name : Prajakta Prasad Palkar',
#   'ROI 4: Father s Name: Prasad Palkar',
#   'ROI 5: House Number : 9\nAge :23 Gander : Female'],
#  ['ROI 1: 37',
#   'ROI 2: TXK7 1076589',
#   'ROI 3: Name * Labin Bagwan',
#   'ROI 4: Father s Name: Mahamadrafik Bagwan',
#   'ROI 5: House Number : 11\nAge : 24 Gender : Male'],
#  ['ROI 1: E 38',
#   'ROI 2: ',
#   'ROI 3: Name : Raghunath VitbugGryahan',
#   'ROI 4: Father s Name: Vita Odean',
#   'ROI 5: House Numbg (itt —'],
#  ['ROI 1: E 39',
#   'ROI 2: FRT0/68214',
#   'ROI 3: Name : Shantabai Ragbqat)Zhauhan',
#   'ROI 4: Husband s Name: aghuraih Chauhan',
#   'ROI 5: House Numb Vw\nAge : 83 Gente: Female'],
#  ['ROI 1: 40',
#   'ROI 2: FRTO774547',
#   'ROI 3: Name : Ashok Kumar Raghunath Chauhan',
#   'ROI 4: Father s Name: Raghunath Chauhan',
#   'ROI 5: House Number : 11\nAge : 63 Gender : Mala'],
#  ['ROI 1: 41',
#   'ROI 2: FRTO766170',
#   'ROI 3: Name : Arundhati Ashok Chauhan',
#   "ROI 4: Husband's Name: Ashok Chauhan",
#   'ROI 5: House Number : 11\nAge : 61 Gender : Female'],
#  ['ROI 1: | 42',
#   'ROI 2: FRT0763979',
#   'ROI 3: Name : Sangram Ashok Kumar Chauhan',
#   'ROI 4: Father s Name: Ashok Kumar Chauhan',
#   'ROI 5: House Number : 11\nAge : 41 Gender : Male'],
#  ['ROI 1: E 43',
#   'ROI 2: FRT0764944',
#   'ROI 3: Name + Madhukar Daji sare',
#   'ROI 4: Father s Name: Datiaien”',
#   'ROI 5: House Numbgs (11\nAge : 94 Geek ala'],
#  ['ROI 1: E 44',
#   'ROI 2: FRTO?61932',
#   'ROI 3: Name : Nisar Maqboo_ Bgavaw',
#   'ROI 4: Father s Name: Maeboyl Bagvan',
#   'ROI 5: House Numbgs (ITE |\nAge : 69 KON ae'],
#  ['ROI 1: | E 45',
#   'ROI 2: FRT0766535',
#   'ROI 3: Name : Rafiq Maqboo_Béavew',
#   'ROI 4: Father s Name: Maeog! Bagvan',
#   'ROI 5: '],
#  ['ROI 1: E Aé',
#   'ROI 2: FRTO761650',
#   'ROI 3: Name : Zahida Nisar Bagganh/',
#   'ROI 4: Husband ‘s Name: btsay Bdgvan',
#   'ROI 5: House Numbes Vw -\nAge : 64 Gegwé, Female'],
#  ['ROI 1: A}',
#   'ROI 2: FRTO0766725',
#   'ROI 3: Name : Abida Bagwan',
#   "ROI 4: Husband's Name: Mahamadrafik Bagwan",
#   'ROI 5: House Number - 114\nAge : 60 Gender : Female'],
#  ['ROI 1: a:',
#   'ROI 2: TXK3093267',
#   'ROI 3: Name : Shaktikumar Ashok Chauhan',
#   "ROI 4: Father's Name: Ashok Chauhan",
#   'ROI 5: House Number : tla\nAge : 42 Gender : Female'],
#  ['ROI 1: 49',
#   'ROI 2: FRT0765198',
#   'ROI 3: Name ’ Kranti Ashok Chauhan',
#   'ROI 4: Father s Name: Ashok Chauhan',
#   'ROI 5: House Number : 11a\nAge : 40 Gender : Female'],
#  ['ROI 1: E 5C',
#   'ROI 2: FRTO0764084',
#   'ROI 3: Name : Chandrakant Satpahgem Shah',
#   'ROI 4: Father s Name: SauhargnvShah',
#   'ROI 5: House Numbgs (il\nAge 92 Gentes Mara'],
#  ['ROI 1: | 51',
#   'ROI 2: FRTO0764407',
#   'ROI 3: Name : Kanchanben Chandrakant Shah',
#   'ROI 4: Husband s Name: Chandrakant Shah',
#   'ROI 5: House Number : 12\nAge : 81 Gender : Female'],
#  ['ROI 1: 52',
#   'ROI 2: FRT0764456',
#   'ROI 3: Name : Rajendrakumar Chandrakant Shah',
#   'ROI 4: Father s Name: Chandrakant Shah',
#   'ROI 5: House Number : 12\nAge : 59 Gender : Male'],
#  ['ROI 1: 53',
#   'ROI 2: TXKO0060210',
#   'ROI 3: Name : Sanjay Kurnar Chandrakant Shah',
#   'ROI 4: Father s Name: Chandrakant Shah',
#   'ROI 5: House Number : 12\nAge - 57 Gender : Male'],
#  ['ROI 1: | 5A',
#   'ROI 2: FRT0764449',
#   'ROI 3: Name : Ashaben Rajendrakumar Shah',
#   "ROI 4: Husband's Name: Rajendrakumar Shah",
#   'ROI 5: House Number : 12\nAge : 54 Gender : Female'],
#  ['ROI 1: ',
#   'ROI 2: FRT0766154',
#   'ROI 3: Name : Atul Kumar Chandrakant Shah',
#   "ROI 4: Father's Name: Chandrakant Shah",
#   'ROI 5: House Number : 12\nAge : 54 Gender : Male'],
#  ['ROI 1: 56',
#   'ROI 2: TXK/305105',
#   'ROI 3: Name : Namrata Sanjay Kumar Shah',
#   'ROI 4: Husband s Name: Sanjay Kumar Shah',
#   "ROI 5: House Number : 12\nAge '51 Gender : Famale"],
#  ['ROI 1: | 57',
#   'ROI 2: FRT0764415',
#   'ROI 3: Name : Aradhana Atul Kumar Shah',
#   'ROI 4: Husband s Name: Atul Kumar Shah',
#   'ROI 5: House Number : 12\nAge : 49 Gender : Famala'],
#  ['ROI 1: S 58',
#   'ROI 2: TXK3036670',
#   'ROI 3: Name : Snehal Amol Vaiary/',
#   'ROI 4: Father s Name: Vijay Ran ifiare',
#   'ROI 5: House Num Vv ;\nAge : 33 Coates, Female'],
#  ['ROI 1: ',
#   'ROI 2: FRT0764191',
#   'ROI 3: Name : Vijay Shankar Ranbhare',
#   'ROI 4: Father s Name: Shankar Ranbhare',
#   'ROI 5: House Number : 12 4\nAge :- 61 Gender : Male'],
#  ['ROI 1: ',
#   'ROI 2: FRT0764183',
#   'ROI 3: Name : Madhun Vijay Ranbhare',
#   'ROI 4: Husband s Name: Vijay Ranbhare',
#   'ROI 5: House Number : 12 A\nAge -54 Gender : Female']]

# %%
import pandas as pd
import re

def preprocess_extracted_data(data):

    processed_data = []

    for item in data:

        part_s_no = item[0].replace('ROI 1:', '').strip()

        if re.match(r'^\s*\|?\s*[ES]\s+\d+', part_s_no):
            continue

        epic_no = item[1].replace('ROI 2:', '').strip()

        voter_name_details = item[2].replace('ROI 3:', '').strip()
        voter_name_details = re.sub(r"[‘’]", '', voter_name_details)
        voter_name_details = re.sub(r'=:', '', voter_name_details)
        voter_name_match = re.search(r"Name\s*[:=+\-*>]?\s*['‘]?([a-zA-Z]+(?:\s[a-zA-Z]+)*)['’]?", voter_name_details, re.IGNORECASE)
        voter_full_name = voter_name_match.group(1).upper() if voter_name_match else ''

        relative_name_details = item[3].replace('ROI 4:', '').strip()
        relative_name_details = re.sub(r"[‘’]", '', relative_name_details)
        relative_match = re.search(r"(Father|Hus[bh]and|Others)\s*(?:[''`$]?\s*[sS]\s*Name)?\s*[:$]*\s*(.+?)(?=\n|$)", relative_name_details, re.IGNORECASE)
        relative_name = relative_match.group(2).upper() if relative_match else ''

        if re.search(r"Hus[bh]and", relative_name_details, re.IGNORECASE):
            relation_type = 'HSBN'
        elif re.search(r"Father", relative_name_details, re.IGNORECASE):
            relation_type = 'FTHR'
        else:
            relation_type = 'OTHR'

        other_details = item[4].replace('ROI 5:', '').strip()
        other_details = other_details.replace('Gander', 'Gender')  
        other_details = other_details.replace('Nurmber', 'Number') 
        other_details = re.sub(r'\s*-\s*', ': ', other_details)  
        other_details = re.sub(r'[\n]+', '\n', other_details)

        age_gender_match = re.search(r'Age\s*[:=\-+]?\s*(\d+|\?+)\s*(?:Gender|Gander|Gente)\s*[:=\-+\'!>]?\s*(Male|Female|Mala)', other_details, re.IGNORECASE)
        age = age_gender_match.group(1).strip() if age_gender_match else ''
        gender = age_gender_match.group(2).strip() if age_gender_match else ''

        if "Fem" in other_details:
            gender = 'F'
        else:
            gender = 'M'

        age = age.replace('?', '7').strip()
        gender = gender.replace('?', '').strip()

        def extract_house_number(text):
            house_number_match = re.search(r'House\s*Nu(?:mber|rmber)\s*[:=]?\s*(.*?)(?=\n|$)', text, re.IGNORECASE)
    
            if house_number_match:
                house_number = house_number_match.group(1).strip()
        
                if house_number.startswith('+') or house_number.startswith('-'):
                    return '-'  
                if re.match(r'^\d+$|^[a-zA-Z\s]+$', house_number):
                    return house_number
        
                return ''  
            return ''
        
        
        processed_data.append([part_s_no, voter_full_name, relative_name, relation_type, age, gender, extract_house_number(other_details), epic_no])

    return processed_data


cleaned_data = preprocess_extracted_data(all_extracted_data)

columns = ["Part S.No", "Voter Full Name", "Relative's Name", "Relation Type", "Age", "Gender", "House No", "EPIC No"]

df = pd.DataFrame(cleaned_data, columns=columns)

output_file = 'final_output_file.xlsx'
df.to_excel(output_file, index=False)

output_file
# Out:
# 'final_output_file.xlsx'
